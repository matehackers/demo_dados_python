# %% [markdown]
# #4. Matplotlip - da real mvp <img src="http://cdn.meme.am/instances/500x/59027138.jpg" align="right" width="30%">

# %% [markdown]
# Instalação:
#
# * Já vem instalada no Data Science Toolkit
#
# Documentação:
#
# * Exemplos: http://matplotlib.org/examples/index.html
# * Galeria: http://matplotlib.org/gallery.html
#
# Objetivo:
#
# * Obter uma representação visual para os dados

# %%
# novamente declara as dependências
from matplotlib import pyplot as plt
import numpy as np

# %%
eixo_x = xrange(500)
eixo_y = np.random.random?

# %%
eixo_y = np.random.randn?

# %%
eixo_y = np.random.randn(500)

# %%
plt.plot(eixo_x, eixo_y)

# %%
plt.scatter(eixo_x, eixo_y)

# %%
plt.hist2d(eixo_x, eixo_y)
# Out:
# (array([[  0.,   0.,   2.,   4.,   6.,  18.,   9.,  10.,   0.,   1.],
#         [  0.,   0.,   1.,  11.,  12.,  10.,  11.,   5.,   0.,   0.],
#         [  0.,   0.,   1.,   8.,   8.,  16.,  11.,   5.,   0.,   1.],
#         [  1.,   0.,   1.,   7.,  13.,  13.,   9.,   4.,   2.,   0.],
#         [  0.,   0.,   1.,   6.,  17.,  11.,   6.,   8.,   1.,   0.],
#         [  0.,   1.,   3.,   5.,  16.,  15.,   1.,   5.,   4.,   0.],
#         [  1.,   1.,   0.,   8.,  15.,  15.,   5.,   3.,   2.,   0.],
#         [  0.,   0.,   1.,   6.,  12.,  11.,  15.,   4.,   1.,   0.],
#         [  1.,   1.,   0.,   7.,  10.,  14.,  13.,   3.,   1.,   0.],
#         [  0.,   0.,   0.,   6.,  11.,  13.,  13.,   6.,   0.,   1.]]),
#  array([   0. ,   49.9,   99.8,  149.7,  199.6,  249.5,  299.4,  349.3,
#          399.2,  449.1,  499. ]),
#  array([-3.6098107 , -2.93130407, -2.25279745, -1.57429082, -0.8957842 ,
#         -0.21727757,  0.46122905,  1.13973568,  1.8182423 ,  2.49674893,
# ...

# %%
Y, Z = np.meshgrid(eixo_x, eixo_x)

# %%
image = [ y*z for y in Y for z in Z]

# %%
plt.imshow(image)
